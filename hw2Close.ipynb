# %% [markdown]
# # INFO-4604 HW2: Linear Classification
#
# * Created by Michael Paul on September 21, 2017
# * Modified by Ryan Close
# ##### Deadline: Friday, September 29, 5:00pm MT

# %% [markdown]
# ## Assignment overview
#
# In this assignment, you will experiment with binary classification on a text dataset. You will be classifying President Trump's official tweets to identify the device from which they were posted, as a proxy for predicting who the tweet was written by. (If you took INFO-2301 last year, you have seen this dataset, but we are using different algorithms this time.)
#
# It is known that Donald Trump uses an Android phone, and it has been observed that some of his tweets come from Android while others come from other devices (most commonly iPhone). It is widely believed that Android tweets are written by Trump himself, while iPhone tweets are written by other staff. For more information, you can read this [blog post by David Robinson](http://varianceexplained.org/r/trump-tweets/), written prior to the election, which finds a number of differences in the style and timing of tweets published under these two devices. (Some tweets are written from other devices, but for simplicity the dataset for this assignment is restricted to these two.)
#
# This is a classification task known as "authorship attribution", which is the task of inferring the author of a document when the authorship is unknown. We will see how accurately this can be done with linear classifiers using word features.
#
# ### What to hand in
#
# You will submit the assignment on Piazza. A private note to the instructor should be submitted with the subject _"Submission 2 from [your full name]"_ with the submission file(s) as an attachment. The note should be submitted to the `submissions` folder (**not** the `hw2` folder).
#
# Submit a single Jupyter notebook named `hw2lastname.ipynb`, where lastname is replaced with your last name.
#
# If you have any output that is not part of your notebook, you may submit that as a separate document, in a single PDF named `hw2lastname.pdf`. For example, this assignment requires you to create plots. You could do it directly with python using [matplotlib](https://matplotlib.org/), but if you wanted to create them using other software, that's acceptable as long as you put all of the figures in a single document and you clearly label them with the corresponding deliverable number.
#
# ### Submission policies
#
# - **Collaboration:** You are allowed to work with up to 3 people besides yourself. You are still expected to write up your own solution. Each individual must post their own submission on Piazza, and you must list the names of your group members in your Piazza note when you submit.
# - **Late submissions:** We allow each student to use up to 5 late days over the semester. You have late days, not late hours. This means that if your submission is late by any amount of time past the deadline, then this will use up a late day. If it is late by any amount beyond 24 hours past the deadline, then this will use a second late, and so on. Once you have used up all late days, late assignments will be given at most 50% credit.
#
# ### Asking for help
#
# You are encouraged to ask questions on [Piazza](https://piazza.com/colorado/fall2017/info4604). Do not post anything that you are turning in, but you can describe general things you observe about the algorithms. You may ask questions to help with debugging, but do not post your code. You can share error messages and describe what you are trying to do with your code, but try not to write enough to "give away" the solution.
#
# Questions specifically about this assignment should be posted in the `hw2` folder. If you have clarifications about what is being asked, you can tag the instructor in your post. If you have more general programming questions (for example, if you are having trouble installing packages, running the notebook, or working with `numpy`), post in the `python` folder. (You can post in multiple folders if both are relevant.)

# %% [markdown]
# ## Getting started
#
# In this assignment, you will experiment with perceptron and logistic regression in `sklearn`. Much of the code has already been written for you. We will use a class called `SGDClassifier` (which you should read about in the [sklearn documentation](http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html)), which  implements stochastic gradient descent (SGD) for a variety of loss functions, including both perceptron and logistic regression, so this will be a way to easily move between the two algorithms.
#
# The code below will load the dataset, which has already been processed for you. There are two collections: the "training" data, which contains the tweets that you will use for training the classifiers, and the "testing" data, which are tweets that you will use to measure the classifier accuracy. The test tweets are instances the classifier has never seen before, so they are a good way to see how the classifier will behave on data it hasn't seen before. However, we still know the labels of the test tweets, so we can measure the accuracy.
#
# For this problem, we will use what are called "bag of words" features, which are commonly used when doing classification with text. Each feature is a word, and the value of a feature for a particular tweet is $1$ if the tweet contains that word and $0$ if not. (There are other ways to assign values to bag of words features, but this binary approach is a simple one that we will use for now.)
#
# Run the block of code below to load the data. You don't need to do anything yet (unless you get an error trying to run the code). Move on to "Problem 1" next.

# %%
import pickle
import numpy as np
from urllib.request import urlopen
from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import SGDClassifier
from sklearn.metrics import accuracy_score, precision_score

data_train = urlopen('http://cmci.colorado.edu/classes/INFO-4604/data/tweets.train.pickle').read()
data_test = urlopen('http://cmci.colorado.edu/classes/INFO-4604/data/tweets.test.pickle').read()

D = np.array(pickle.loads(data_train))
Y = D[:,0]
v = DictVectorizer(sparse=True)
X = v.fit_transform(D[:,1])
feature_names = np.asarray(v.get_feature_names())

D_test = np.array(pickle.loads(data_test))
Y_test = D_test[:,0]
X_test = v.transform(D_test[:,1])

# %% [markdown]
# ## Problem 1: Understand the data [6 points]
#
# Before doing anything else, let's take the time to understand the code above and what the variables `D`, `Y`, and `X` contain.
#
# First, if you are unfamiliar with `pickle` in python, this is a way of writing the contents of a python variable to a file. The variables `D` and `D_test` were stored in files and have been loaded again. These variables contain an array of instances, where each instance is a list of two things: first, a string label, and second, a dictionary of features that are present in the instance.
#
# For example, if an instance's features are represented by the dictionary `{'see' : 1, 'you' : 1, 'tonight' : 1}`, this means that those three words were present in the tweet, while the values of all other word features are assumed to be $0$. [`DictVectorizer`](http://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.DictVectorizer.html) converts this dictionary representation into a feature vector representation that `sklearn` can use.
#
# You should print out the values of the variables and write any other code needed to answer the following questions.
#
# #### Deliverable 1.1: How many training instances are in the dataset? How many test instances?
#
# Training: 48243 Test: 3456
#
# #### Deliverable 1.2: How many features are in the training data?
#
# 2 Features
#
# #### Deliverable 1.3: What is the distribution of labels in the training data? That is, what percentage of instances are 'Android' versus 'iPhone'?

# %%
print (D);
print (Y);
print (X);
print (D_test);
print (Y_test);
print (X_test);
# Out:
# [['Android'
#   {'USERNAME': 1, 'on': 1, 'story': 1, 'whats': 1, 'happening': 1, 'reference': 1, 'that': 1, 'was': 1, 'concerning': 1, 'immigrants': 1, 'sweden': 1, 'broadcast': 1, 'to': 1, 'as': 1, 'statement': 1, 'in': 1, 'my': 1}]
#  ['Android'
#   {'house': 1, 'meetings': 1, 'at': 1, 'in': 1, 'will': 1, 'to': 1, 'speech': 1, 'lot': 1, 'white': 1, 'be': 1, 'big': 1, 'southern': 1, 'weekend': 1, 'about': 1, 'this': 1, 'many': 1, 'florida': 1, 'melbourne': 1, '5:00': 1, 'the': 1, 'having': 1, 'talk': 1}]
#  ['Android'
#   {'and': 1, 'dont': 1, 'stream': 1, 'process': 1, 'house': 1, 'is': 1, 'fake': 1, 'am': 1, 'it': 1, 'in': 1, 'media': 1, 'very': 1, 'inherited': 1, 'white': 1, 'main': 1, 'mess': 1, 'running': 1, 'news': 1, 'believe': 1, 'of': 1, 'well': 1, 'fixing': 1, 'the': 1}]
#  ...,
#  ['iPhone'
#   {'be': 1, 'great': 1, 'arizona': 1, 'URL': 1, '#makeamericagreatagain': 1, 'back': 1, 'to': 1, 'in': 1, '#trump2016': 1}]
#  ['Android'
#   {'crazy': 1, 'show': 1, 'is': 1, 'in': 1, 'if': 1, 'ratings': 1, 'would': 1, 'ways': 1, 'much': 1, 'USERNAME': 1, 'totally': 1, 'me': 1, 'on': 1, 'tank': 1, 'her': 1, 'many': 1, 'average': 1, 'cover': 1, 'terrible': 1, 'so': 1, 'she': 1, 'didnt': 1}]
#  ['Android'
#   {'and': 1, 'crazy': 1, 'says': 1, 'dont': 1, 'show': 1, 'almost': 1, 'all': 1, 'are': 1, 'go': 1, 'still': 1, 'ratings': 1, 'her': 1, 'negative': 1, 'gets': 1, 'shows': 1, 'USERNAME': 1, 'me': 1, 'good': 1, 'but': 1, 'wont': 1, 'on': 1, 'hits': 1, 'of': 1, 'she': 1}]]
# ['Android' 'Android' 'Android' ..., 'iPhone' 'Android' 'Android']
#   (0, 423)	1.0
#   (0, 671)	1.0
#   (0, 927)	1.0
#   (0, 1229)	1.0
#   (0, 2248)	1.0
#   (0, 2434)	1.0
#   (0, 2447)	1.0
#   (0, 3123)	1.0
#   (0, 3272)	1.0
#   (0, 3785)	1.0
#   (0, 4303)	1.0
#   (0, 4335)	1.0
#   (0, 4416)	1.0
#   (0, 4500)	1.0
#   (0, 4566)	1.0
#   (0, 4877)	1.0
#   (0, 4924)	1.0
#   (1, 352)	1.0
#   (1, 436)	1.0
#   (1, 683)	1.0
#   (1, 761)	1.0
#   (1, 820)	1.0
#   (1, 1994)	1.0
#   (1, 2275)	1.0
#   (1, 2386)	1.0
#   :	:
#   (2591, 5002)	1.0
#   (2592, 423)	1.0
#   (2592, 543)	1.0
#   (2592, 555)	1.0
#   (2592, 588)	1.0
#   (2592, 648)	1.0
#   (2592, 962)	1.0
#   (2592, 1346)	1.0
#   (2592, 1632)	1.0
#   (2592, 2128)	1.0
#   (2592, 2147)	1.0
#   (2592, 2162)	1.0
#   (2592, 2308)	1.0
#   (2592, 2345)	1.0
#   (2592, 2967)	1.0
#   (2592, 3157)	1.0
#   (2592, 3250)	1.0
#   (2592, 3272)	1.0
#   (2592, 3737)	1.0
#   (2592, 4020)	1.0
#   (2592, 4127)	1.0
#   (2592, 4154)	1.0
#   (2592, 4157)	1.0
#   (2592, 4323)	1.0
#   (2592, 4981)	1.0
# [['Android'
#   {'on': 1, 'low-life': 1, 'be': 1, 'leakers': 1, 'caught': 1, 'been': 1, 'will': 1, 'finally': 1, 'they': 1, 'put': 1, 'the': 1, 'has': 1, 'spotlight': 1}]
#  ['iPhone'
#   {'signing': 1, 'trump': 1, 'URL': 1, 'of': 1, '41': 1, 'at': 1, 'remarks': 1, 'president': 1, 'resolution': 1, 'by': 1}]
#  ['iPhone'
#   {'prime': 1, 'on': 1, 'korea': 1, 'north': 1, 'abe': 1, 'shinzo': 1, 'URL': 1, 'joint': 1, 'minister': 1, 'statement': 1, '#icymi': 1, 'with': 1}]
#  ['Android'
#   {'all': 1, 'just': 1, 'win': 1, 'is': 1, 'down': 1, 'doesnt': 1, 'at': 1, 'in': 1, 'our': 1, 'anymore': 1, 'how': 1, 'long': 1, 'to': 1, 'bogged': 1, 'over': 1, 'conflict': 1, 'hero': 1, 'mess': 1, 'know': 1, 'he': 1, 'look': 1, 'country': 1, 'place': 1, 'the': 1}]
#  ['Android'
#   {'disgrace': 1, 'is': 1, 'it': 1, 'obstruction': 1, 'democrats': 1, 'in': 1, 'our': 1, 'still': 1, 'delay': 1, 'full': 1, 'that': 1, 'cabinet': 1, 'longest': 1, 'not': 1, 'such': 1, 'by': 1, 'of': 1, 'place': 1, 'country': 1, 'the': 1, 'my': 1, 'history': 1}]
#  ['Android'
#   {'and': 1, 'conflict': 1, 'lawyers': 1, 'federal': 1, 'boston': 1, 'decision': 1, 'court': 1, 'looking': 1, 'ridiculous': 1, 'lift': 1, 'at': 1, 'which': 1, 'in': 1, 'ban': 1, 'using': 1, 'the': 1, 'with': 1, 'why': 1, 'is': 1, 'arent': 1}]
#  ['Android'
#   {'and': 1, 'hard': 1, 'as': 1, 'governor': 1, 'yes': 1, 'worse': 1, 'tried': 1, 'even': 1, 'least': 1, 'apprentice': 1, 'really': 1, 'schwarzenegger': 1, 'but': 1, 'job': 1, 'california': 1, 'he': 1, 'on': 1, 'did': 1, 'of': 1, 'arnold': 1, 'bad': 1, 'the': 1, 'at': 1}]
#  ['Android'
#   {'obstruct': 1, 'obama': 1, 'now': 1, 'an': 1, 'have': 1, 'for': 1, 'to': 1, 'reasons': 1, 'delaying': 1, 'political': 1, 'but': 1, 'cabinet': 1, 'purely': 1, 'going': 1, 'democrats': 1, 'they': 1, 'nothing': 1, 'the': 1, 'picks': 1, 'my': 1, 'are': 1}]
#  ['iPhone'
#   {'we': 1, 'remember': 1, 'space': 1, '#neverforget': 1, 'of': 1, '31': 1, 'later': 1, 'URL': 1, 'crew': 1, 'challenger': 1, 'shuttle': 1, 'the': 1, 'years': 1, 'today': 1}]
#  ['Android'
#   {'billion': 1, 'from': 1, 'deal': 1, 'mexico': 1, 'numbers': 1, 'beginning': 1, 'nafta': 1, 'dollar': 1, 'it': 1, 'been': 1, 'trade': 1, '60': 1, 'deficit': 1, 'one-sided': 1, 'of': 1, 'the': 1, 'has': 1, 'with': 1, 'massive': 1}]
#  ['iPhone'
#   {'be': 1, 'lower': 1, 'thank': 1, 'abbas': 1, 'that': 1, 'upper': 1, 'photo': 1, 'displayed': 1, 'yesterday': 1, 'you': 1, 'will': 1, 'URL': 1, 'in': 1, 'press': 1, 'delivered': 1, 'the': 1, 'hall': 1}]
#  ['iPhone'
#   {'be': 1, 'people': 1, 'remembered': 1, 'january': 1, 'this': 1, 'day': 1, 'will': 1, 'rulers': 1, 'as': 1, 'became': 1, 'of': 1, 'again': 1, '2017': 1, 'nation': 1, 'the': 1, '20th': 1}]
#  ['iPhone'
#   {'ago': 1, 'weeks': 1, 'winter': 1, 'URL': 1, 'house': 1, 'friday': 1, 'inaugural': 1, 'writing': 1, 'looking': 1, 'to': 1, 'at': 1, 'mar-a-lago': 1, 'address': 1, 'forward': 1, 'the': 1, 'three': 1, 'my': 1, 'white': 1}]
#  ['Android'
#   {'USERNAME': 1, 'and': 1, 'use': 1, 'media': 1, 'very': 1, 'of': 1, 'twitter': 1, 'appreciate': 1, 'us': 1, 'keep': 1, 'to': 1, 'maintain': 1, 'transparency': 1, 'informed': 1, 'your': 1, 'dishonest': 1}]
#  ['Android'
#   {'be': 1, 'unaffordable': 1, 'soon': 1, 'will': 1, 'act': 1, 'the': 1, 'history': 1, 'care': 1}]
#  ['Android'
#   {'me': 1, 'do': 1, 'use': 1, 'tried': 1, 'no': 1, 'loans': 1, 'over': 1, 'never': 1, 'deals': 1, 'to': 1, 'have': 1, 'nothing': 1, 'has': 1, 'with': 1, 'russia': 1, 'leverage': 1}]
#  ['Android'
#   {'says': 1, 'mexico': 1, 'wall': 1, 'is': 1, 'fake': 1, 'if': 1, 'little': 1, 'built': 1, 'for': 1, 'media': 1, 'quickly': 1, 'paying': 1, 'more': 1, 'be': 1, 'they': 1, 'wont': 1, 'later': 1, 'dishonest': 1, 'so': 1, 'can': 1, 'pay': 1, 'the': 1}]
#  ['iPhone'
#   {'trump': 1, 'office': 1, 'am': 1, 'at': 1, 'steven': 1, 'go': 1, 'wintour': 1, 'editors': 1, 'to': 1, 'friend': 1, 'conde': 1, 'ask': 1, 'with': 1, 'the': 1, 'me': 1, 'nast': 1, 'this': 1, 'of': 1, 'will': 1, 'newhouse': 1, 'anna': 1, 'meet': 1, 'tower': 1, 'my': 1, 'came': 1}]
#  ['Android'
#   {'and': 1, 'is': 1, 'it': 1, 'democrats': 1, 'in': 1, 'what': 1, 'working': 1, 'to': 1, 'fix': 1, 'obamacare': 1, 'how': 1, 'schumer': 1, 'instead': 1, 'head': 1, 'mess': 1, 'know': 1, 'they': 1, 'by': 1, 'lead': 1, 'of': 1, 'chuck': 1, 'clown': 1, 'bad': 1, 'the': 1, 'are': 1}]
#  ['Android'
#   {'and': 1, 'tax': 1, 'focus': 1, 'one': 1, 'reform': 1, 'things': 1, 'priority': 1, 'their': 1, 'other': 1, 'many': 1, 'be': 1, 'greater': 1, 'may': 1, 'act': 1, '#dts': 1, 'number': 1, 'importance': 1, 'on': 1, 'of': 1, 'so': 1, 'healthcare': 1, 'far': 1}]
#  ['Android'
#   {'USERNAME': 1, 'and': 1, 'russians': 1, 'for': 1, 'funny': 1, 'watch': 1, 'it': 1, 'clue': 1, 'to': 1, 'have': 1, 'are': 1, 'they': 1, 'such': 1, 'fools': 1, 'gets': 1, 'totally': 1, 'playing': 1, 'dont': 1}]
#  ['Android'
#   {'and': 1, 'everyone': 1, 'very': 1, 'to': 1, 'merry': 1, 'year': 1, 'new': 1, 'christmas': 1, 'happy': 1}]
#  ['iPhone'
#   {'be': 1, 'regarding': 1, 'united': 1, 'cont': 1, 'vetoed': 1, 'being': 1, 'URL': 1, 'israel': 1, 'nations': 1, 'considered': 1, 'at': 1, 'council': 1, 'the': 1, 'should': 1, 'resolution': 1, 'security': 1}]
#  ['iPhone'
#   {'and': 1, 'rips': 1, 'united': 1, 'takes': 1, 'of': 1, 'waters': 1, 'act': 1, 'water': 1, 'it': 1, 'research': 1, 'states': 1, 'to': 1, 'drone': 1, 'china': 1, 'in': 1, 'navy': 1, 'international': 1, 'unprecedented': 1, 'steals': 1, 'out': 1}]
#  ['Android'
#   {'all': 1, 'dealing': 1, 'is': 1, 'successfully': 1, 'at': 1, 'best': 1, 'rex': 1, 'tillerson': 1, 'types': 1, 'has': 1, 'that': 1, 'he': 1, 'with': 1, 'vast': 1, 'governments': 1, 'about': 1, 'like': 1, 'of': 1, 'experience': 1, 'foreign': 1, 'thing': 1, 'the': 1}]
#  ['Android'
#   {'great': 1, 'for': 1, 'kennedy': 1, 'senate': 1, 'of': 1, 'is': 1, 'friday': 1, 'spent': 1, 'state': 1, 'won': 1, 'election': 1, 'louisiana': 1, 'campaigning': 1, 'the': 1, 'john': 1, 'with': 1, 'over': 1}]
#  ['iPhone'
#   {'and': 1, 'glenn': 1, 'in': 1, 'missed': 1, 'space': 1, 'pioneer': 1, 'john': 1, 'was': 1, 'today': 1, 'be': 1, 'we': 1, 'hero': 1, 'explorers': 1, 'he': 1, 'great': 1, 'lost': 1, 'of': 1, 'inspired': 1, 'air': 1, 'will': 1, 'future': 1, 'generations': 1}]
#  ['Android'
#   {'and': 1, 'wisconsin': 1, 'votes': 1, 'in': 1, 'stein': 1, 'just': 1, 'pennsylvania': 1, 'money': 1, 'is': 1, 'suit': 1, 'to': 1, 'scam': 1, 'green': 1, 'dropped': 1, 'recount': 1, 'losing': 1, 'party': 1, 'the': 1, 'its': 1, 'raise': 1}]
#  ['iPhone'
#   {'arena': 1, 'me': 1, 'cincinnati': 1, 'for': 1, '7pm': 1, 'URL': 1, 'join': 1, 'rally': 1, 'to': 1, 'tickets': 1, 'in': 1, 'ohio': 1, 'heading': 1, 'bank': 1}]
#  ['iPhone'
#   {'and': 1, 'trump': 1, 'URL': 1, 'nominate': 1, 'price': 1, 'verma': 1, 'intends': 1, 'to': 1, 'donald': 1, 'tom': 1, 'congressman': 1, 'president-elect': 1, 'seema': 1}]
#  ['Android'
#   {'and': 1, 'then': 1, 'we': 1, 'said': 1, 'have': 1, 'democracy': 1, 'that': 1, 'this': 1, 'is': 1, 'direct': 1, 'accept': 1, 'results': 1, 'to': 1, 'donald': 1, 'future': 1, 'election': 1, 'threat': 1, 'look': 1, 'our': 1, 'the': 1, 'she': 1}]
#  ['Android'
#   {'the': 1, 'great': 1, 'run': 1, 'trump': 1, 'for': 1, 'people': 1, 'of': 1, 'meetings': 1, 'who': 1, 'next': 1, 'will': 1, 'government': 1, 'place': 1, 'take': 1, 'our': 1, 'formation': 1, 'tower': 1, 'years': 1, 'concerning': 1, 'today': 1, 'at': 1}]
#  ['Android'
#   {'and': 1, 'be': 1, 'all': 1, 'who': 1, 'helping': 1, 'working': 1, 'again': 1, 'make': 1, 'men': 1, 'great': 1, 'will': 1, 'to': 1, 'choosing': 1, 'in': 1, 'the': 1, 'america': 1, 'weekend': 1, 'women': 1}]
#  ['Android'
#   {'and': 1, 'on': 1, 'all': 1, 'their': 1, 'very': 1, 'win': 1, 'express': 1, 'george': 1, 'jeb': 1, 'to': 1, 'bush': 1, 'wishes': 1, 'the': 1, 'called': 1, 'best': 1, 'nice': 1}]
#  ['Android'
#   {'USERNAME': 1, 'entire': 1, 'just': 1, 'problems': 1, 'utah': 1, 'according': 1, 'machine': 1, 'to': 1, 'officials': 1, 'country': 1, 'report': 1, 'voting': 1, 'across': 1, 'out': 1}]
#  ['iPhone'
#   {'arena': 1, 'all': 1, 'north': 1, 'just': 1, 'dorton': 1, 'URL': 1, '#makeamericagreatagain': 1, 'see': 1, 'you': 1, 'to': 1, 'landed': 1, 'lets': 1, 'in': 1, 'the': 1, 'soon': 1, 'heading': 1, 'carolina': 1}]
#  ['iPhone'
#   {'all': 1, 'clinton': 1, 'campaign': 1, 'no': 1, 'URL': 1, 'top': 1, 'bemoan': 1, 'aides': 1, 'tactics': 1, 'vision': 1}]
#  ['iPhone'
#   {'nh': 1, 'we': 1, 'save': 1, 'end': 1, 'thank': 1, 'all': 1, 'drugs': 1, 'illegal': 1, 'aliens': 1, 'stop': 1, 'immigration': 1, 'watc': 1, 'will': 1, 'URL': 1, 'american': 1, 'lives': 1, 'you': 1, 'criminal': 1, 'deport': 1, 'the': 1}]
#  ['iPhone'
#   {'and': 1, 'hillarys': 1, 'crooked': 1, 'of': 1, 'is': 1, 'after': 1, 'URL': 1, 'lies': 1, 'in': 1, 'scandal': 1, 'closing': 1, 'decades': 1, 'corruption': 1, '#draintheswamp': 1}]
#  ['iPhone'
#   {'promises': 1, 'trump': 1, 'URL': 1, 'obamacare': 1, 'to': 1, 'session': 1, 'repeal': 1, 'special': 1}]
#  ['iPhone'
#   {'beautiful': 1, 'evening': 1, 'thank': 1, 'mexico': 1, 'this': 1, 'in': 1, 'watch': 1, 'albuquerque': 1, 'URL': 1, 'get': 1, 'new': 1, 'vote': 1, 'rally': 1, 'you': 1, '#draintheswamp': 1, 'out': 1}]
#  ['Android'
#   {'be': 1, 'colorado': 1, 'big': 1, 'am': 1, 'yesterday': 1, 'but': 1, 'as': 1, 'planned': 1, 'in': 1, 'nothing': 1, 'day': 1, 'can': 1}]
#  ['iPhone'
#   {'charlotte': 1, 'all': 1, 'north': 1, 'feedback': 1, 'delivered': 1, 'URL': 1, 'of': 1, 'support': 1, 'appreciate': 1, 'yesterday': 1, 'lets': 1, 'speech': 1, 'in': 1, '#maga': 1, 'the': 1, 'carolina': 1}]
#  ['iPhone'
#   {'charlotte': 1, 'great': 1, 'full': 1, 'north': 1, 'thank': 1, 'delivered': 1, 'URL': 1, 'renewal': 1, 'speech': 1, 'afternoon': 1, '#icymi': 1, 'you': 1, 'on': 1, 'urban': 1, 'carolina': 1}]
#  ['iPhone' {'URL': 1, '#obamacarefail': 1}]
#  ['iPhone'
#   {'augustine': 1, '7pm': 1, 'palm': 1, 'at': 1, 'in': 1, 'rally': 1, 'st': 1, 'for': 1, 'west': 1, 'to': 1, 'beach': 1, 'be': 1, 'URL': 1, '3pm': 1, 'now': 1, 'tampa': 1, 'me': 1, 'join': 1, 'florida': 1, 'leaving': 1, 'will': 1, 'heading': 1}]
#  ['iPhone'
#   {'lead': 1, 'touch': 1, 'to': 1, 'URL': 1, 'turns': 1, 'everything': 1, 'clintons': 1, 'so': 1, 'are': 1, 'they': 1, 'corrupt': 1, 'the': 1, 'former': 1, 'prosecutor': 1, 'molten': 1}]
#  ['iPhone'
#   {'thank': 1, 'pennsylvania': 1, 'gettysburg': 1, 'URL': 1, 'you': 1, '#draintheswamp': 1}]
#  ['iPhone'
#   {'11': 1, 'on': 1, 'great': 1, 'thank': 1, 'crowd': 1, 'get': 1, 'pennsylvania': 1, 'URL': 1, 'watch': 1, 'movement': 1, 'this': 1, 'pa': 1, 'afternoon': 1, 'in': 1, 'vote': 1, 'you': 1, 'out': 1, 'the': 1, 'johnstown': 1}]
#  ['iPhone'
#   {'do': 1, 'we': 1, 'to': 1, 'islamic': 1, 'this': 1, 'radical': 1, 'stop': 1, 'URL': 1, 'will': 1, 'elected': 1, 'in': 1, 'need': 1, 'terrorism': 1, 'country': 1, 'potus': 1, 'order': 1, 'if': 1}]
#  ['iPhone'
#   {'what': 1, 'long': 1, 'isis': 1, 'they': 1, 'doing': 1, 'been': 1, 'will': 1, 'URL': 1, 'leadership': 1, 'too': 1, 'have': 1, 'defeat': 1, 'our': 1, 'has': 1, '#draintheswamp': 1, 'around': 1}]
#  ['iPhone'
#   {'use': 1, 'clinton': 1, 'for': 1, 'illegals': 1, 'provide': 1, 'of': 1, 'dollars': 1, 'URL': 1, 'tax': 1, 'hillary': 1, 'will': 1, 'to': 1, 'american': 1, 'put': 1, 'amnesty': 1, 'thousands': 1}]
#  ['iPhone'
#   {'and': 1, 'illegally': 1, 'clinton': 1, 'for': 1, 'URL': 1, 'hard': 1, 'state': 1, 'works': 1, '#draintheswamp': 1}]
#  ['iPhone'
#   {'and': 1, 'cover-ups': 1, 'crooked': 1, 'collusion': 1, 'will': 1, 'URL': 1, 'bribery': 1, 'pay-to-play': 1, 'so': 1, 'now': 1, '#draintheswamp': 1}]
#  ['Android'
#   {'USERNAME': 1, 'great': 1, 'after': 1, 'from': 1, 'especially': 1, 'just': 1, 'media': 1, 'wow': 1, 'polls': 1, 'ohio': 1, 'job': 1, 'numbers': 1, '48': 1, 'leading': 1, 'hit': 1, 'new': 1, 'total': 1, '44': 1, 'came': 1, 'out': 1}]
#  ['Android'
#   {'we': 1, 'clinton': 1, 'nominee': 1, 'crooked': 1, 'always': 1, 'pushing': 1, 'political': 1, 'ryan': 1, 'machine': 1, 'hillary': 1, 'democrats': 1, 'have': 1, 'corrupt': 1, 'fighting': 1, 'the': 1, 'republican': 1, 'paul': 1}]
#  ['Android'
#   {'USERNAME': 1, 'even': 1, 'dont': 1, 'anymore': 1, 'sources': 1, 'just': 1, 'failing': 1, 'up': 1, 'us': 1, 'write': 1, 'to': 1, 'way': 1, 'call': 1, 'whatever': 1, 'they': 1, 'reporters': 1, 'making': 1, 'the': 1, 'along': 1, 'want': 1}]
#  ['iPhone'
#   {'me': 1, 'north': 1, 'URL': 1, '2:00pm': 1, 'at': 1, 'in': 1, 'join': 1, '#trumprally': 1, 'tomorrow': 1, 'greensboro': 1, 'carolina': 1}]
#  ['Android'
#   {'USERNAME': 1, 'town': 1, 'given': 1, 'fraud': 1, 'clinton': 1, 'debates': 1, 'big': 1, 'advance': 1, 'crooked': 1, 'of': 1, 'wow': 1, 'in': 1, 'against': 1, 'to': 1, 'hillary': 1, 'sanders': 1, 'questions': 1, 'were': 1, 'cnn': 1, 'hall': 1, 'bernie': 1}]
#  ['Android'
#   {'USERNAME': 1, 'and': 1, 'group': 1, 'look': 1, 'pathetic': 1, 'to': 1, 'crooked': 1, 'fixing': 1, 'wow': 1, 'dishonest': 1, 'focus': 1, 'order': 1, 'better': 1, 'their': 1, 'hillary': 1, 'in': 1, 'got': 1, 'really': 1, 'totally': 1, 'caught': 1, 'make': 1}]
#  ['iPhone'
#   {'dornsife': 1, 'usc': 1, 'trump': 1, 'lead': 1, 'la': 1, 'URL': 1, 'retains': 1, 'over': 1, 'point': 1, 'donald': 1, 'times': 1, 'sunday': 1, 'poll': 1, 'hillary': 1}]
#  ['iPhone' {'URL': 1, 'new': 1, 'national': 1, 'poll': 1, 'rasmussen': 1}]
#  ['iPhone'
#   {'and': 1, 'in': 1, 'your': 1, 'thank': 1, 'for': 1, 'media': 1, 'to': 1, 'you': 1, 'issue': 1, 'USERNAME': 1, 'be': 1, 'arizona': 1, 'great': 1, 'yesterday': 1, 'important': 1, 'remarks': 1, 'on': 1, 'kind': 1, 'of': 1, 'dishonest': 1, 'the': 1, 'ptsd': 1}]
#  ['iPhone'
#   {'USERNAME': 1, '#bigleaguetruth': 1, 'for': 1, 'URL': 1, 'is': 1, '#vpdebate': 1, 'wrong': 1, 'defense': 1}]
#  ['Android'
#   {'USERNAME': 1, 'great': 1, 'no': 1, 'doing': 1, 'is': 1, 'contest': 1, 'far': 1, 'job': 1, 'so': 1}]
#  ['iPhone'
#   {'we': 1, 'arizona': 1, 'thank': 1, 'this': 1, 'is': 1, 'nobody': 1, 'URL': 1, 'together': 1, 'like': 1, 'to': 1, 'america': 1, 'going': 1, 'safe': 1, 'are': 1, 'before': 1, 'seen': 1, 'you': 1, 'has': 1, 'ever': 1, 'make': 1, 'movement': 1}]
#  ['Android'
#   {'will': 1, 'we': 1, 'for': 1, 'again': 1, 'pennsylvania': 1, 'big': 1, 'make': 1, 'great': 1, 'tonight': 1, 'to': 1, 'rally': 1, 'america': 1, 'heading': 1}]
#  ['Android'
#   {'and': 1, 'angel': 1, 'is': 1, 'an': 1, 'past': 1, 'as': 1, 'miss': 1, 'her': 1, 'crooked': 1, 'wow': 1, 'duped': 1, 'which': 1, 'was': 1, 'used': 1, 'checking': 1, 'floated': 1, 'hillary': 1, 'worst': 1, 'by': 1, 'terrible': 1, 'without': 1, 'my': 1}]
#  ['Android'
#   {'me': 1, 'has': 1, 'thank': 1, 'for': 1, 'to': 1, 'fox': 1, 'time': 1, 'debate': 1, 'winning': 1, 'etc': 1, 'magazine': 1, 'you': 1, 'every': 1, 'drudge': 1, 'so': 1, 'the': 1, 'poll': 1, 'friends': 1, 'on-line': 1, 'reporting': 1}]
#  ['iPhone'
#   {'clinton': 1, 'trump': 1, 'URL': 1, 'billionaire': 1, 'is': 1, 'hillary': 1, 'donald': 1, 'of': 1, 'touch': 1, 'out': 1, 'true': 1, 'blue-collar': 1, 'shows': 1}]
#  ['iPhone'
#   {'USERNAME': 1, 'ransom': 1, '#debatenight': 1, 'for': 1, 'URL': 1, 'nuclear': 1, 'million': 1, 'agreement': 1, 'way': 1, '400': 1, 'the': 1, 'payment': 1, 'paved': 1}]
#  ['iPhone'
#   {'roanoke': 1, 'join': 1, 'thank': 1, 'up': 1, 'this': 1, '#americafirst': 1, 'virginia': 1, 'us': 1, 'sign': 1, 'URL': 1, 'you': 1, 'today': 1, 'movement': 1}]
#  ['Android'
#   {'USERNAME': 1, 'be': 1, 'tonight': 1, 'from': 1, 'on': 1, 'enjoy': 1, 'interviewed': 1, '10:00': 1, 'will': 1, 'at': 1, 'cleveland': 1, 'ohio': 1}]
#  ['Android'
#   {'now': 1, 'isis': 1, 'for': 1, 'crooked': 1, 'is': 1, 'ideas': 1, 'fighting': 1, 'years': 1, 'whatever': 1, 'doing': 1, 'hillary': 1, 'been': 1, 'time': 1, 'it': 1, 'new': 1, 'has': 1, 'or': 1, 'change': 1, 'she': 1}]
#  ['Android'
#   {'gone': 1, 'laughingstock': 1, 'rag': 1, 'doing': 1, 'is': 1, 'say': 1, 'are': 1, 'crooked': 1, 'nuts': 1, 'to': 1, 'willing': 1, 'has': 1, 'USERNAME': 1, 'badly': 1, 'that': 1, 'hillary': 1, 'they': 1, 'anything': 1, 'failing': 1, 'so': 1, 'become': 1, 'the': 1}]
#  ['iPhone'
#   {'and': 1, 'worlds': 1, 'great': 1, 'creation': 1, 'jobs': 1, 'wealth': 1, 'driving': 1, 'URL': 1, 'of': 1, 'away': 1, 'innovation': 1, 'magnet': 1, 'for': 1, 'will': 1, 'job': 1, 'become': 1, 'instead': 1, 'the': 1, 'america': 1}]
#  ['iPhone'
#   {'me': 1, 'join': 1, 'thank': 1, 'miami': 1, 'friday': 1, 'florida': 1, 'see': 1, 'to': 1, 'cant': 1, 'URL': 1, 'in': 1, 'you': 1, 'wait': 1}]
#  ['Android'
#   {'and': 1, 'give': 1, 'feel': 1, 'twitter': 1, 'am': 1, 'as': 1, 'in': 1, 'our': 1, 'saw': 1, 'pray': 1, 'speech': 1, 'hope': 1, 'USERNAME': 1, 'though': 1, 'with': 1, 'me': 1, 'on': 1, 'room': 1, 'success': 1, 'optimism': 1, 'ur': 1, 'the': 1}]
#  ['Android'
#   {'is': 1, 'years': 1, 'case': 1, 'second': 1, 'said': 1, 'for': 1, 'no': 1, 'writer': 1, 'to': 1, 'book': 1, 'jilted': 1, 'USERNAME': 1, 'do': 1, 'wanted': 1, 'who': 1, 'feels': 1, 'now': 1, 'with': 1, 'me': 1, 'dummy': 1, 'hostile': 1, 'basket': 1}]
#  ['Android' {'USERNAME': 1, 'on': 1, 'up': 1, 'coming': 1}]
#  ['iPhone' {'URL': 1, 'you': 1, '#americafirst': 1, 'thank': 1}]
#  ['Android'
#   {'clinton': 1, 'fbi': 1, 'documents': 1, 'stood': 1, 'for': 1, 'lyin': 1, 'how': 1, 'she': 1, 'be': 1, 'that': 1, 'hillary': 1, 'markings': 1, 'know': 1, 'not': 1, 'on': 1, 'happening': 1, 'did': 1, 'classified': 1, 'this': 1, 'can': 1, 'the': 1, 'told': 1}]
#  ['Android'
#   {'and': 1, '#maga': 1, 'want': 1, 'people': 1, 'an': 1, 'have': 1, 'our': 1, 'ground': 1, 'army': 1, 'by': 1, 'to': 1, 'surprised': 1, 'be': 1, 'we': 1, 'very': 1, 'game': 1, 'they': 1, 'nov': 1, 'with': 1, 'spirit': 1, 'on': 1, 'great': 1, 'of': 1, 'will': 1, 'volunteers': 1}]
#  ['Android'
#   {'president': 1, 'bomb': 1, 'mexico': 1, 'fox': 1, 'is': 1, 'railing': 1, 'for': 1, 'to': 1, 'visit': 1, 'also': 1, 'apologized': 1, 'today': 1, 'vicente': 1, 'who': 1, 'using': 1, 'former': 1, 'he': 1, 'me': 1, 'invited': 1, 'when': 1, 'against': 1, 'the': 1, 'my': 1}]
#  ['Android'
#   {'USERNAME': 1, 'independents': 1, 'via': 1, 'trump': 1, 'crowd': 1, 'dems': 1, 'of': 1, 'is': 1, 'minorities': 1, 'URL': 1, 'at': 1, 'sea': 1, 'in': 1, 'akron': 1, 'rally': 1, 'ohio': 1, 'women': 1}]
#  ['iPhone'
#   {'join': 1, 'URL': 1, 'polls': 1, '#imwithyou': 1, 'new': 1, 'the': 1, 'today': 1, 'movement': 1}]
#  ['iPhone'
#   {'needs': 1, '#flashbackfriday': 1, 'clinton': 1, 'campaign': 1, 'her': 1, 'URL': 1, 'of': 1, 'undertones': 1, 'to': 1, 'hillary': 1, 'racist': 1, 'address': 1, 'the': 1, '2008': 1}]
#  ['iPhone'
#   {'thank': 1, 'for': 1, '#imwithyou': 1, 'support': 1, '#americafirst': 1, 'URL': 1, 'you': 1, 'your': 1}]
#  ['iPhone'
#   {'USERNAME': 1, 'saying': 1, 'we': 1, 'sure': 1, 'trump': 1, 'people': 1, 'is': 1, 'am': 1, 'ann': 1, 'knowing': 1, 'it': 1, 'its': 1, 'terrific': 1, 'book': 1, 'are': 1, 'in': 1, 'new': 1, 'trust': 1, 'tomorrow': 1, 'comes': 1, 'out': 1}]
#  ['iPhone'
#   {'and': 1, 'again': 1, 'we': 1, 'URL': 1, 'make': 1, 'safe': 1, 'great': 1, 'together': 1, 'to': 1, 'going': 1, 'are': 1, 'america': 1}]
#  ['iPhone'
#   {'in': 1, 'great': 1, 'last': 1, 'thank': 1, 'for': 1, 'louisiana': 1, 'nc': 1, 'mi': 1, 'success': 1, 'heading': 1, 'tonight': 1, 'to': 1, 'another': 1, 'speech': 1, 'reception': 1, 'evenings': 1, 'you': 1, 'now': 1, 'was': 1, 'the': 1}]
#  ['iPhone'
#   {'on': 1, 'losses': 1, 'financial': 1, 'plans': 1, 'insurer': 1, 'URL': 1, 'is': 1, 'persistent': 1, 'back': 1, 'due': 1, 'to': 1, 'only': 1, 'pulling': 1, 'another': 1, 'health': 1, 'the': 1, 'beginning': 1, '#obamacare': 1}]
#  ['Android'
#   {'USERNAME': 1, 'and': 1, 'all': 1, 'throughout': 1, 'god': 1, 'positive': 1, 'inspired': 1, 'mr': 1, 'well': 1, 'america': 1, 'youve': 1, 'bless': 1, 'as': 1, 'were': 1, 'you': 1, 'enjoying': 1, 'spirit': 1, 'hope': 1, 'nice': 1}]
#  ['Android'
#   {'USERNAME': 1, 'about': 1, 'URL': 1, 'media': 1, 'avoid': 1, 'hillaryclinton': 1, 'against': 1, 'controversy': 1, 'to': 1, 'corrupt': 1, 'the': 1, 'creats': 1, 'issues': 1}]
#  ['Android'
#   {'and': 1, 'amendment': 1, 'fantastic': 1, 'is': 1, 'in': 1, 'as': 1, 'dumb': 1, 'defending': 1, 'lightweight': 1, 'lemon': 1, 'you': 1, 'USERNAME': 1, 'on': 1, 'night': 1, 'were': 1, 'don': 1, 'me': 1, 'both': 1, 'last': 1, 'second': 1, 'rock': 1, 'the': 1}]
#  ['iPhone' {'URL': 1, 'you': 1, 'thank': 1}]
#  ['Android'
#   {'poor': 1, 'badly': 1, 'all': 1, 'clinton': 1, 'her': 1, 'for': 1, 'what': 1, 'being': 1, 'is': 1, 'answering': 1, 'see': 1, 'us': 1, 'criticized': 1, 'hillary': 1, 'let': 1, 'questions': 1, 'in': 1, 'performance': 1, 'happens': 1}]
#  ['iPhone'
#   {'pence': 1, 'join': 1, 'to': 1, 'URL': 1, 'wi': 1, 'looking': 1, 'ia': 1, 'us': 1, 'forward': 1, '#maga': 1, 'gov': 1, 'with': 1, 'tomorrow': 1}]
#  ['iPhone' {'#imwithyou': 1, 'URL': 1, 'you': 1, 'thank': 1, 'virginia': 1}]
#  ['iPhone'
#   {'real': 1, 'life': 1, 'from': 1, 'disconnected': 1, 'sit': 1, 'chairs': 1, 'fundraisers': 1, 'support': 1, 'who': 1, 'people': 1, 'behind': 1, 'or': 1, 'headline': 1, 'hillary': 1, 'cnn': 1, 'the': 1, 'anchor': 1, 'those': 1}]
#  ['Android'
#   {'and': 1, 'leaders': 1, 'radical': 1, 'is': 1, 'it': 1, 'years': 1, 'our': 1, 'captain': 1, 'khan': 1, 'to': 1, 'terror': 1, 'was': 1, 'hero': 1, 'weakness': 1, 'but': 1, 'islamic': 1, 'killed': 1, 'ago': 1, 'about': 1, '12': 1, 'this': 1, 'of': 1, 'the': 1, 'eradicate': 1}]
#  ['Android'
#   {'and': 1, 'love': 1, 'from': 1, 'colorado': 1, 'just': 1, 'incredible': 1, 'big': 1, 'rallies': 1, 'back': 1, 'two': 1, 'at': 1, 'enthusiasm': 1, 'got': 1, 'the': 1, 'was': 1, 'crowds': 1}]
#  ['iPhone'
#   {'me': 1, 'join': 1, 'colorado': 1, 'URL': 1, 'denver': 1, 'tonight': 1, '7pm': 1, 'at': 1, 'in': 1, 'springs': 1, '2pm': 1, 'or': 1}]
#  ['Android'
#   {'and': 1, 'diego': 1, 'shot': 1, 'san': 1, 'just': 1, 'getting': 1, 'is': 1, 'policemen': 1, 'people': 1, 'two': 1, 'dead': 1, 'one': 1, 'only': 1, 'want': 1, 'in': 1, 'it': 1, 'law': 1, 'order': 1, 'worse': 1}]
#  ['iPhone' {'URL': 1, 'future': 1, 'americas': 1}]
#  ['Android'
#   {'enemy': 1, 'bomb': 1, 'that': 1, 'just': 1, 'vice': 1, 'very': 1, 'stated': 1, 'ted': 1, 'cruz': 1, 'biden': 1, 'bright': 1, 'joe': 1, 'president': 1, 'not': 1, 'our': 1, 'the': 1, 'wanted': 1, 'was': 1, 'sorry': 1, 'to': 1, 'carpet': 1}]
#  ['iPhone'
#   {'and': 1, 'liar': 1, 'it': 1, 'proven': 1, 'invention': 1, 'in': 1, 'her': 1, 'crooked': 1, 'to': 1, 'has': 1, 'incompetent': 1, 'be': 1, 'that': 1, 'very': 1, 'hillary': 1, 'both': 1, 'for': 1, 'of': 1, 'email': 1, 'thing': 1, 'bad': 1, 'the': 1}]
#  ['iPhone' {'URL': 1, 'ohio': 1, 'you': 1, 'thank': 1, '#trumppence16': 1}]
#  ['Android'
#   {'schultz': 1, 'and': 1, 'cheating': 1, 'her': 1, 'that': 1, 'crooked': 1, 'is': 1, 'after': 1, 'neurotic': 1, 'shes': 1, 'to': 1, 'hillary': 1, 'wasserman': 1, 'debbie': 1, 'way': 1, 'stealing': 1, 'the': 1, 'highly': 1, 'out': 1, 'angry': 1, 'victory': 1}]
#  ['iPhone' {'URL': 1, '#makeamericagreatagain': 1, '#trumppence16': 1}]
#  ['Android'
#   {'general': 1, 'to': 1, 'just': 1, 'how': 1, 'of': 1, 'defeat': 1, 'michael': 1, 'highly': 1, 'field': 1, 'book': 1, 'recommend': 1, 'islam': 1, 'radical': 1, 'the': 1, 'fight': 1, 'by': 1, 'flynn': 1, 'out': 1}]
#  ['Android'
#   {'USERNAME': 1, 'will': 1, 'fantastic': 1, 'be': 1, 'great': 1, 'tonight': 1, 'was': 1}]
#  ['iPhone'
#   {'URL': 1, '#makeamericaworkagain': 1, '#rncincle': 1, '#trumppence16': 1}]
#  ['Android'
#   {'USERNAME': 1, 'and': 1, 'all': 1, 'stacked': 1, 'dont': 1, 'for': 1, 'far': 1, 'is': 1, 'watch': 1, 'negative': 1, 'better': 1, 'crooked': 1, 'hillary': 1, 'much': 1, 'guests': 1, 'which': 1, 'truthful': 1, 'than': 1, 'are': 1, 'more': 1}]
#  ['Android'
#   {'done': 1, 'in': 1, 'from': 1, 'start': 1, 'to': 1, 'state': 1, 'forward': 1, 'indiana': 1, 'has': 1, 'introducing': 1, 'mike': 1, 'spectacular': 1, 'who': 1, 'choice': 1, 'job': 1, 'great': 1, 'look': 1, 'of': 1, 'governor': 1, 'pence': 1, 'the': 1, 'my': 1, 'first': 1}]
#  ['iPhone'
#   {'and': 1, 'diego': 1, 'myself': 1, 'san': 1, 'for': 1, 'on': 1, 'spending': 1, 'money': 1, 'also': 1, 'am': 1, 'helping': 1, 'to': 1, 'lot': 1, 'way': 1, 'others': 1, 'party': 1, 'the': 1, 'republican': 1, 'my': 1, 'raise': 1}]
#  ['iPhone'
#   {'all': 1, 'voters': 1, 'global': 1, 'trade': 1, 'want': 1, 'open': 1, 'special': 1, 'people': 1, 'arms': 1, 'to': 1, 'you': 1, 'interests': 1, 'we': 1, 'welcome': 1, 'who': 1, 'stop': 1, 'with': 1, 'deals': 1, 'bad': 1, 'the': 1, 'bernie': 1, 'first': 1}]
#  ['Android'
#   {'people': 1, 'dead': 1, 'one': 1, 'heard': 1, 'are': 1, 'politics': 1, 'network': 1, 'that': 1, 'few': 1, 'john': 1, 'was': 1, 'USERNAME': 1, 'watching': 1, 'happily': 1, 'underachieving': 1, 'on': 1, 'king': 1, 'hour': 1, 'lies': 1, 'of': 1, 'inside': 1, 'the': 1}]
#  ['Android'
#   {'and': 1, 'love': 1, 'just': 1, 'people': 1, 'senate': 1, 'house': 1, 'meetings': 1, 'are': 1, 'in': 1, 'our': 1, 'interesting': 1, 'had': 1, 'republicans': 1, 'very': 1, 'who': 1, 'with': 1, 'day': 1, 'great': 1, 'these': 1, 'country': 1, 'leaving': 1, 'the': 1}]
#  ['Android'
#   {'raised': 1, 'money': 1, 'are': 1, 'in': 1, 'for': 1, 'lots': 1, 'support': 1, 'there': 1, 'when': 1, 'lot': 1, 'win': 1, 'party': 1, 'announced': 1, 'be': 1, 'big': 1, 'gasp': 1, 'republican': 1, 'of': 1, 'morning': 1, 'will': 1, 'figures': 1, 'the': 1}]
#  ['Android'
#   {'and': 1, 'just': 1, 'danger': 1, 'it': 1, 'go': 1, 'need': 1, 'crooked': 1, 'able': 1, 'to': 1, 'be': 1, 'we': 1, 'handle': 1, 'never': 1, 'hillary': 1, 'change': 1, 'on': 1, 'forever': 1, 'isis': 1, 'of': 1, 'will': 1, 'complexities': 1, 'the': 1}]
#  ['iPhone' {'URL': 1, 'you': 1, '#americafirst': 1, 'thank': 1}]
#  ['iPhone'
#   {'was': 1, 'what': 1, 'believe': 1, 'clinton': 1, 'look': 1, 'just': 1, 'that': 1, 'meeting': 1, 'is': 1, 'bill': 1, 'system': 1, 'anybody': 1, 'coincidence': 1, 'does': 1, 'at': 1, 'rigged': 1, 'take': 1, 'the': 1, 'really': 1, 'totally': 1, 'happened': 1}]
#  ['iPhone'
#   {'and': 1, 'again': 1, 'we': 1, 'america': 1, '#trump2016': 1, 'deal': 1, 'URL': 1, 'win': 1, 'make': 1, 'great': 1, 'to': 1, 'going': 1, 'are': 1, 'new': 1, 'the': 1, 'poll': 1, 'whole': 1, 'out': 1}]
#  ['Android'
#   {'heritage': 1, 'senators': 1, 'productive': 1, 'elizabeth': 1, 'lied': 1, 'on': 1, 'crooked': 1, 'of': 1, 'is': 1, 'who': 1, 'least': 1, 'one': 1, 'senate': 1, 'hillary': 1, 'goofy': 1, 'in': 1, 'warren': 1, 'the': 1, 'wheeling': 1, 'out': 1}]
#  ['Android'
#   {'one': 1, 'pundits': 1, 'george': 1, 'hes': 1, 'political': 1, 'long': 1, 'way': 1, 'party': 1, 'has': 1, 'his': 1, 'who': 1, 'most': 1, 'republican': 1, 'ago': 1, 'made': 1, 'calls': 1, 'lost': 1, 'of': 1, 'will': 1, 'bad': 1, 'overrated': 1, 'many': 1, 'the': 1, 'left': 1}]
#  ['Android'
#   {'and': 1, 'saying': 1, 'disaster': 1, 'is': 1, 'it': 1, 'need': 1, 'brexit': 1, 'would': 1, 'crooked': 1, 'totally': 1, 'to': 1, 'be': 1, 'we': 1, 'hillary': 1, 'now': 1, 'with': 1, 'obama': 1, 'on': 1, 'her': 1, 'wrong': 1, 'lead': 1, 'she': 1, 'went': 1, 'called': 1}]
#  ['Android'
#   {'USERNAME': 1, 'hillarys': 1, 'brilliant': 1, 'slogan': 1, 'URL': 1, 'to': 1, 'im': 1, 'word': 1, 'you': 1, 'with': 1, 'response': 1}]
#  ['iPhone'
#   {'arizona': 1, 'love': 1, 'thank': 1, 'URL': 1, '#americafirst': 1, 'you': 1, '#trump2016': 1}]
#  ['Android'
#   {'USERNAME': 1, 'on': 1, 'good': 1, 'desperate': 1, 'media': 1, 'is': 1, 'but': 1, 'keep': 1, 'thing': 1, 'attack': 1, 'are': 1, 'they': 1, 'in': 1, 'news': 1, 'the': 1, 'relentless': 1, '#trump': 1}]
#  ['iPhone'
#   {'be': 1, 'north': 1, 'thank': 1, 'URL': 1, '#americafirst': 1, 'back': 1, 'soon': 1, 'will': 1, 'you': 1, 'greensboro': 1, 'carolina': 1}]
#  ['Android'
#   {'and': 1, 'be': 1, '2:30': 1, 'yesterday': 1, 'of': 1, 'horrible': 1, 'primary': 1, 'hampshire': 1, 'events': 1, 'will': 1, 'to': 1, 'going': 1, 'victory': 1, 'home': 1, 'terror': 1, 'new': 1, 'the': 1, 'my': 1, 'discuss': 1, 'today': 1, 'first': 1}]
#  ['iPhone'
#   {'#trumptrain': 1, 'thank': 1, 'URL': 1, 'florida': 1, '#americafirst': 1, 'you': 1, 'tampa': 1}]
#  ['Android'
#   {'again': 1, 'productive': 1, 'elizabeth': 1, 'senators': 1, 'of': 1, 'is': 1, 'she': 1, 'it': 1, 'least': 1, 'one': 1, 'choice': 1, 'goofy': 1, 'mouth': 1, 'at': 1, 'the': 1, 'has': 1, 'pocahontas': 1, 'nasty': 1, 'hope': 1, 'warren': 1}]
#  ['Android'
#   {'USERNAME': 1, 'votes': 1, 'usa': 1, 'for': 1, 'of': 1, 'is': 1, 'reporting': 1, 'most': 1, 'in': 1, 'president': 1, 'the': 1, 'where': 1, 'why': 1, 'history': 1}]
#  ['Android'
#   {'be': 1, 'about': 1, 'toward': 1, 'that': 1, 'country': 1, 'continues': 1, 'great': 1, 'will': 1, 'to': 1, 'again': 1, 'journey': 1, 'at': 1, 'wins': 1, 'our': 1, 'the': 1, 'republican': 1, 'nomination': 1, '9:00': 1, 'speaking': 1, 'movement': 1}]
#  ['Android'
#   {'USERNAME': 1, '#potus': 1, 'look': 1, 'everything': 1, 'make': 1, 'mr': 1, '#makeamericagreatagain': 1, 'great': 1, '#elkhart': 1, 'to': 1, 'ineffective': 1, 'speech': 1, 'in': 1, 'our': 1, 'has': 1, 'trump': 1}]
#  ['Android'
#   {'38': 1, 'jobs': 1, 'just': 1, 'terrible': 1, 'bombshell': 1, 'reported': 1, 'only': 1, '000': 1, 'report': 1, 'added': 1}]
#  ['Android'
#   {'USERNAME': 1, 'restore': 1, 'great': 1, 'trump': 1, 'for': 1, 'country': 1, 'is': 1, 'to': 1, 'vote': 1, 'our': 1}]
#  ['Android'
#   {'USERNAME': 1, 'for': 1, 'slackers': 1, 'took': 1, 'courses': 1, 'thanks': 1, 'not': 1, 'happy': 1}]
#  ['Android'
#   {'case': 1, 'easily': 1, 'biased': 1, 'who': 1, 'trump': 1, 'on': 1, 'university': 1, 'gonzalo': 1, 'but': 1, 'should': 1, 'judgement': 1, 'me': 1, 'won': 1, 'against': 1, 'have': 1, 'judge': 1, 'the': 1, 'summary': 1, 'totally': 1, 'is': 1, 'curiel': 1}]
#  ['iPhone'
#   {'control': 1, 'own': 1, 'tough': 1, 'be': 1, 'embarrassed': 1, 'cant': 1, 'are': 1, 'if': 1, 'for': 1, 'rs': 1, 'been': 1, 'their': 1, '2yrs-an': 1, 'party': 1, 'has': 1, 'gop': 1, 'then': 1, 'kristol': 1, 'but': 1, 'wrong': 1, 'they': 1, 'not': 1, 'bill': 1, 'loser': 1, 'the': 1}]
#  ['iPhone'
#   {'25': 1, 'san': 1, 'diego': 1, 'URL': 1, 'wow': 1, '000': 1, 'california': 1, 'in': 1, 'you': 1, '#trump2016': 1, 'thank': 1}]
#  ['Android'
#   {'and': 1, 'clinton': 1, 'deal': 1, 'it': 1, 'cant': 1, 'doesnt': 1, 'have': 1, 'close': 1, 'out': 1, 'just': 1, 'crooked': 1, 'had': 1, 'to': 1, 'candidates': 1, 'smart': 1, 'good': 1, 'very': 1, 'hillary': 1, 'with': 1, 'knock': 1, '16': 1, 'the': 1, 'bernie': 1}]
#  ['iPhone'
#   {'USERNAME': 1, 'story': 1, 'thank': 1, 'for': 1, 'this': 1, 'straight': 1, 'failing': 1, 'what': 1, 'should': 1, 'nyts': 1, 'URL': 1, 'written': 1, 'setting': 1, 'have': 1, 'the': 1, 'you': 1, 'is': 1}]
#  ['iPhone'
#   {'shot': 1, 'single': 1, 'dopey': 1, 'networks': 1, 'for': 1, 'when': 1, 'to': 1, 'has': 1, 'USERNAME': 1, 'do': 1, 'wrong': 1, 'every': 1, 'put': 1, 'why': 1, 'he': 1, 'me': 1, 'on': 1, 'about': 1, 'yrs': 1, 'continue': 1, 'the': 1, 'panels': 1, 'called': 1}]
#  ['Android'
#   {'USERNAME': 1, 'play': 1, 'to': 1, 'links': 1, '16': 1, 'URL': 1, 'ailsa': 1, 'june': 1, 'cant': 1, 'it': 1, 'course': 1, 'britain': 1, 'opens': 1, 'in': 1, 'best': 1, 'wait': 1}]
#  ['Android'
#   {'be': 1, 'supreme': 1, 'weeks': 1, 'court': 1, 'to': 1, 'was': 1, 'very': 1, 'of': 1, 'list': 1, 'number': 1, 'next': 1, 'may': 1, 'potential': 1, 'adding': 1, 'justices': 1, 'recieved': 1, 'during': 1, 'the': 1, 'my': 1, 'well': 1}]
#  ['Android'
#   {'rigged': 1, 'on': 1, 'clinton': 1, 'look': 1, 'e-mail': 1, 'crooked': 1, 'is': 1, 'get': 1, 'democrat': 1, 'debating': 1, 'it': 1, 'to': 1, 'hillary': 1, 'investigation': 1, 'so': 1, 'are': 1, 'time': 1, 'forward': 1, 'primaries': 1}]
#  ['Android'
#   {'USERNAME': 1, 'do': 1, 'we': 1, 'love': 1, 'great': 1, 'actually': 1, 'you': 1, 'really': 1}]
#  ['Android'
#   {'USERNAME': 1, 'on': 1, 'what': 1, 'talked': 1, 'watching': 1, 'fox': 1, 'two': 1, 'to': 1, 'cant': 1, 'hear': 1, 'about': 1, 'you': 1, 'now': 1, 'with': 1, 'wait': 1}]
#  ['Android'
#   {'and': 1, 'is': 1, 'back': 1, 'years': 1, 'say': 1, 'what': 1, 'said': 1, 'for': 1, 'no': 1, 'res': 1, 'to': 1, 'does': 1, 'call': 1, 'come': 1, 'that': 1, 'company': 1, 'not': 1, 'trying': 1, 'endlessly': 1, 'would': 1, 'barbara': 1, 'she': 1, 'my': 1}]
#  ['Android'
#   {'USERNAME': 1, 'votes': 1, 'everyone': 1, 'thank': 1, 'away': 1, 'continues': 1, 'but': 1, 'to': 1, 'donald': 1, 'pile': 1, 'can': 1, 'they': 1, 'our': 1, 'take': 1, 'you': 1, 'onto': 1, 'never': 1}]
#  ['iPhone' {'URL': 1, '#trump2016': 1, '#makeamericagreatagain': 1}]
#  ['iPhone' {'URL': 1, '#trump2016': 1, '#votetrump': 1, '#wvprimary': 1}]
#  ['Android'
#   {'USERNAME': 1, 'be': 1, 'on': 1, 'this': 1, 'enjoy': 1, 'interviewed': 1, 'morning': 1, 'will': 1}]
#  ['iPhone'
#   {'will': 1, 'them': 1, 'clinton': 1, 'elizabeth': 1, 'her': 1, 'both': 1, 'chooses': 1, 'running': 1, 'hillary': 1, 'goofy': 1, 'mate': 1, 'defeat': 1, 'corrupt': 1, 'as': 1, 'hope': 1, 'warren': 1}]
#  ['Android'
#   {'USERNAME': 1, 'be': 1, 'on': 1, 'enjoy': 1, 'interviewed': 1, 'will': 1, 'at': 1, '7:30': 1}]
#  ['iPhone'
#   {'again': 1, 'great': 1, 'URL': 1, 'make': 1, '#inprimary': 1, '#votetrump': 1, 'america': 1}]
#  ['iPhone'
#   {'thank': 1, 'URL': 1, 'haute': 1, 'terre': 1, '#makeamericagreatagain': 1, 'indiana': 1, 'you': 1}]
#  ['Android'
#   {'all': 1, 'clinton': 1, 'is': 1, 'one': 1, 'have': 1, 'for': 1, 'to': 1, 'crooked': 1, 'also': 1, 'ever': 1, 'run': 1, 'enablers': 1, 'most': 1, 'hillary': 1, 'great': 1, 'presidency': 1, 'of': 1, 'dishonest': 1, 'perhaps': 1, 'person': 1, 'time': 1, 'the': 1}]
#  ['Android'
#   {'and': 1, 'we': 1, 'staying': 1, 'bad': 1, 'just': 1, 'people': 1, 'had': 1, 'fantastic': 1, 'express': 1, 'am': 1, 'great': 1, 'new': 1, 'rally': 1, 'inn': 1, 'at': 1, 'clean': 1, 'in': 1, 'not': 1, 'indiana': 1, 'holiday': 1, 'where': 1}]
#  ['iPhone' {'URL': 1, 'you': 1, 'maryland': 1, '#trump2016': 1, 'thank': 1}]
#  ['iPhone'
#   {'thank': 1, '#riprimary': 1, 'island': 1, 'URL': 1, 'rhode': 1, '#votetrump': 1, 'warwick': 1, 'you': 1}]
#  ['iPhone'
#   {'#trumptrain': 1, 'thank': 1, 'URL': 1, 'delaware': 1, '#makeamericagreatagain': 1, 'you': 1, '#trump2016': 1}]
#  ['Android'
#   {'and': 1, 'enjoy': 1, 'major': 1, '7a': 1, 'doing': 1, 'it': 1, 'rest': 1, 'in': 1, 'family': 1, 'hopefully': 1, 'USERNAME': 1, 'be': 1, 'melania': 1, 'with': 1, 'hall': 1, 'town': 1, 'wife': 1, 'of': 1, 'will': 1, 'fun': 1, 'the': 1, 'my': 1}]
#  ['iPhone' {'URL': 1, 'you': 1, 'thank': 1, 'eric': 1}]
#  ['iPhone'
#   {'and': 1, 'thank': 1, 'pennsylvania': 1, '#makeamericagreatagain': 1, 'URL': 1, 'connecticut': 1, 'california': 1, 'you': 1, '#trump2016': 1, 'maryland': 1}]
#  ['iPhone'
#   {'me': 1, 'join': 1, '16': 1, 'this': 1, '#trump2016': 1, 'noon': 1, '#nyprimary': 1, 'watertown': 1, 'URL': 1, '3pm': 1, 'weekend': 1, 'syracuse': 1}]
#  ['iPhone'
#   {'and': 1, 'thank': 1, 'pennsylvania': 1, '#makeamericagreatagain': 1, 'soon': 1, 'URL': 1, 'see': 1, 'california': 1, 'york': 1, 'new': 1, 'you': 1, '#trump2016': 1, 'maryland': 1}]
#  ['Android'
#   {'great': 1, 'never': 1, 'primary': 1, 'colorado': 1, 'that': 1, 'of': 1, 'is': 1, 'people': 1, 'unfair': 1, 'it': 1, 'anger': 1, 'possible': 1, 'how': 1, 'state': 1, 'in': 1, 'vote': 1, 'got': 1, 'the': 1, 'republican': 1, 'totally': 1, 'to': 1}]
#  ['Android'
#   {'USERNAME': 1, 'co': 1, 'URL': 1, 'here': 1, 'gop': 1, 'very': 1, 'replaced': 1, 'at': 1, 'convention': 1, 'sad': 1, 'your': 1, 'delegate': 1}]
#  ['Android'
#   {'USERNAME': 1, 'on': 1, 'great': 1, '#newday': 1, '#makeamericagreatagain': 1, 'regarding': 1, 'to': 1, 'victory': 1, 'interview': 1, 'path': 1, 'with': 1}]
#  ['iPhone'
#   {'we': 1, 'good': 1, 'wisconsin': 1, 'URL': 1, 'polls': 1, 'morning': 1, 'will': 1, '#votetrump': 1, 'are': 1, 'makeamericagreatagain': 1, 'the': 1, 'now': 1, 'open': 1, 'today': 1}]
#  ['iPhone'
#   {'USERNAME': 1, 'congratulations': 1, 'for': 1, 'all': 1, 'of': 1, 'proud': 1, 'we': 1, 'winning': 1, 'to': 1, 'clubs': 1, 'going': 1, 'great': 1, 'are': 1, 'the': 1, 'you': 1}]
#  ['iPhone'
#   {'USERNAME': 1, 'on': 1, 'use': 1, 'full': 1, 'statements': 1, 'thank': 1, 'for': 1, 'they': 1, 'would': 1, 'nuclear': 1, 'never': 1, 'fox': 1, 'agree': 1, 'with': 1, 'words': 1, 'which': 1, 'you': 1, 'my': 1, 'your': 1, 'today': 1, 'nice': 1}]
#  ['iPhone'
#   {'USERNAME': 1, 'and': 1, 'priebus': 1, 'just': 1, 'very': 1, 'with': 1, 'bringing': 1, 'had': 1, 'it': 1, 'together': 1, 'looking': 1, 'to': 1, 'will': 1, 'forward': 1, 'party': 1, 'the': 1, 'meeting': 1, 'happen': 1, 'nice': 1}]
#  ['iPhone'
#   {'changed': 1, 'from': 1, 'her': 1, 'facility': 1, 'this': 1, 'my': 1, 'there': 1, 'when': 1, 'URL': 1, 'tape': 1, 'she': 1, 'statement': 1, 'reporters': 1, 'found': 1, 'the': 1, 'was': 1, 'tune': 1, 'out': 1}]
#  ['Android'
#   {'so-called': 1, 'from': 1, 'leaders': 1, 'learn': 1, 'when': 1, 'gitmo': 1, 'an': 1, 'will': 1, 'released': 1, 'american': 1, 'detainee': 1, 'our': 1, 'has': 1, 'ever': 1, 'killed': 1}]
#  ['Android'
#   {'clinton': 1, 'dont': 1, 'just': 1, 'general': 1, 'are': 1, 'another': 1, 'in': 1, 'USERNAME': 1, 'hit': 1, 'easily': 1, 'beat': 1, 'phony': 1, 'job': 1, 'they': 1, 'believe': 1, 'me': 1, 'on': 1, 'polls': 1, 'hillary': 1, 'will': 1, 'the': 1, 'election': 1}]
#  ['Android'
#   {'trump': 1, 'just': 1, 'certain': 1, 'it': 1, 'press': 1, 'in': 1, 'if': 1, 'lost-monster': 1, 'story': 1, 'federal': 1, 'write': 1, 'to': 1, 'won': 1, 'big': 1, 'but': 1, 'refuses': 1, 'lawsuit': 1, 'case': 1, 'about': 1, 'ways': 1, 'the': 1, 'similar': 1}]
#  ['Android'
#   {'USERNAME': 1, 'politician': 1, 'thank': 1, 'for': 1, 'hes': 1, 'god': 1, 'is': 1, 'who': 1, 'people': 1, 'but': 1, 'one': 1, 'will': 1, 'heck': 1, 'us': 1, 'of': 1, 'not': 1, 'fighter': 1, 'the': 1, 'fight': 1}]
#  ['iPhone'
#   {'#trumptrain': 1, 'arizona': 1, 'thank': 1, 'URL': 1, '#westerntuesday': 1, 'you': 1, '#trump2016': 1}]
#  ['Android'
#   {'will': 1, 'be': 1, 'big': 1, 'there': 1, 'tonight': 1, 'dinner': 1, 'palm': 1, 'at': 1, 'mar-a-lago': 1, 'in': 1, 'republican': 1, 'beach': 1}]
#  ['Android'
#   {'all': 1, 'because': 1, 'trump': 1, 'are': 1, 'networks': 1, 'ratings': 1, 'wow': 1, 'its': 1, 'USERNAME': 1, 'again': 1, '75': 1, 'off': 1, 'america': 1, 'me': 1, 'great': 1, 'fortune': 1, 'of': 1, 'up': 1, 'time': 1, 'making': 1, 'the': 1, 'make': 1}]]
# ['Android' 'iPhone' 'iPhone' 'Android' 'Android' 'Android' 'Android'
#  'Android' 'iPhone' 'Android' 'iPhone' 'iPhone' 'iPhone' 'Android'
#  'Android' 'Android' 'Android' 'iPhone' 'Android' 'Android' 'Android'
#  'Android' 'iPhone' 'iPhone' 'Android' 'Android' 'iPhone' 'Android'
#  'iPhone' 'iPhone' 'Android' 'Android' 'Android' 'Android' 'Android'
#  'iPhone' 'iPhone' 'iPhone' 'iPhone' 'iPhone' 'iPhone' 'Android' 'iPhone'
#  'iPhone' 'iPhone' 'iPhone' 'iPhone' 'iPhone' 'iPhone' 'iPhone' 'iPhone'
#  'iPhone' 'iPhone' 'iPhone' 'Android' 'Android' 'Android' 'iPhone'
#  'Android' 'Android' 'iPhone' 'iPhone' 'iPhone' 'iPhone' 'Android' 'iPhone'
#  'Android' 'Android' 'Android' 'iPhone' 'iPhone' 'iPhone' 'Android'
#  'Android' 'Android' 'iPhone' 'iPhone' 'Android' 'Android' 'Android'
#  'iPhone' 'Android' 'Android' 'Android' 'Android' 'iPhone' 'iPhone'
#  'iPhone' 'iPhone' 'iPhone' 'iPhone' 'iPhone' 'Android' 'Android' 'Android'
#  'iPhone' 'Android' 'iPhone' 'iPhone' 'iPhone' 'Android' 'Android' 'iPhone'
#  'Android' 'iPhone' 'Android' 'iPhone' 'iPhone' 'Android' 'iPhone'
#  'Android' 'Android' 'iPhone' 'Android' 'Android' 'iPhone' 'iPhone'
#  'Android' 'Android' 'Android' 'Android' 'iPhone' 'iPhone' 'iPhone'
#  'Android' 'Android' 'Android' 'Android' 'iPhone' 'Android' 'iPhone'
#  'Android' 'iPhone' 'Android' 'Android' 'Android' 'Android' 'Android'
#  'Android' 'Android' 'Android' 'iPhone' 'iPhone' 'Android' 'iPhone'
#  'iPhone' 'Android' 'Android' 'Android' 'Android' 'Android' 'Android'
#  'Android' 'iPhone' 'iPhone' 'Android' 'iPhone' 'Android' 'iPhone' 'iPhone'
#  'Android' 'Android' 'iPhone' 'iPhone' 'iPhone' 'Android' 'iPhone' 'iPhone'
#  'iPhone' 'iPhone' 'Android' 'Android' 'Android' 'iPhone' 'iPhone' 'iPhone'
#  'iPhone' 'iPhone' 'Android' 'Android' 'Android' 'Android' 'iPhone'
#  'Android' 'Android']
#   (0, 761)	1.0
#   (0, 776)	1.0
#   (0, 1039)	1.0
#   (0, 1954)	1.0
#   (0, 2262)	1.0
#   (0, 2875)	1.0
#   (0, 3272)	1.0
#   (0, 3687)	1.0
#   (0, 4502)	1.0
#   (0, 4516)	1.0
#   (0, 4948)	1.0
#   (1, 323)	1.0
#   (1, 422)	1.0
#   (1, 683)	1.0
#   (1, 966)	1.0
#   (1, 3250)	1.0
#   (1, 3571)	1.0
#   (1, 3826)	1.0
#   (1, 4171)	1.0
#   (1, 4649)	1.0
#   (2, 77)	1.0
#   (2, 422)	1.0
#   (2, 428)	1.0
#   (2, 2619)	1.0
#   (2, 2691)	1.0
#   :	:
#   (183, 4511)	1.0
#   (183, 4579)	1.0
#   (183, 4948)	1.0
#   (184, 382)	1.0
#   (184, 423)	1.0
#   (184, 505)	1.0
#   (184, 543)	1.0
#   (184, 573)	1.0
#   (184, 648)	1.0
#   (184, 770)	1.0
#   (184, 2041)	1.0
#   (184, 2189)	1.0
#   (184, 2587)	1.0
#   (184, 2912)	1.0
#   (184, 2915)	1.0
#   (184, 2967)	1.0
#   (184, 3172)	1.0
#   (184, 3250)	1.0
#   (184, 3251)	1.0
#   (184, 3737)	1.0
#   (184, 4502)	1.0
#   (184, 4558)	1.0
#   (184, 4649)	1.0
#   (184, 4757)	1.0
#   (184, 5006)	1.0

# %% [markdown]
# ## Problem 2: Perceptron [6 points]
#
# The code below trains an [`SGDClassifier`](http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html) using the perceptron loss, then it measures the accuracy of the classifier on the test data, using `sklearn`'s [`accuracy_score`](http://scikit-learn.org/stable/modules/generated/sklearn.metrics.accuracy_score.html) function.
#
# The `fit` function trains the classifier. The feature weights are stored in the `coef_` variable after training. The `predict` function of the trained `SGDClassifier` outputs the predicted label for a given instance or list of instances.
#
# Additionally, this code displays the features and their weights in sorted order, which you may want to examine to understand what the classifier is learning. In this dataset, the $\textrm{Android}$ class is considered the "negative" class because it comes first, so if a feature has a negative weight, this means it is predictive of $\textrm{Android}$, while a feature with a positive weight is predictive of the $\textrm{iPhone}$ class.
#
# There are 3 keyword arguments that have been added to the code below. It is important you keep the same values of these arguments whenever you create an `SGDClassifier` instance in this assignment so that you get consistent results. They are:
#
# - `max_iters` is one of the stopping criteria, which is the maximum number of iterations/epochs the algorithm will run for.
#
# - `tol` is the other stopping criterion, which is how small the difference between the current loss and previous loss should be before stopping.
#
# - `random_state` is a seed for pseudorandom number generation. The algorithm uses randomness in the way the training data are sorted, which will affect the solution that is learned, and even the accuracy of that solution.
#
# Wait a minute $-$ in class we learned that the loss function is convex, so the algorithm will find the same minimum regardless of how it is trained. Why is there random variation in the output? The reason is that even though there is only one minimum value of the loss, there may be different weights that result in the same loss, so randomness is a matter of tie-breaking. What's more, while different weights may have the same loss, they could lead to different classification accuracies, because the loss function is not the same as accuracy. (Unless accuracy was your loss function... which is possible, but uncommon because it turns out to be a difficult function to optimize.)
#
# To begin, run the code in the cell below without modification.
#
# #### Deliverable 2.1: Based on the training accuracy, do you conclude that the data are linearly separable? Why or why not?
#
# [your answer here]
#
# #### Deliverable 2.2: Which feature most increases the likelihood that the class is 'iPhone'? Based on the description of the dataset, why do you think this is the case?
#
# [your answer here]
#
# <br />
#
# One technique for improving the resulting model with perceptron (or stochastic gradient descent learning in general) is to take an average of the weight vectors learned at different iterations of the algorithm, rather than only using the final weights that minimize the loss. That is, calculate $\bar{\mathbf{w}} = \sum_{t=1}^T \mathbf{w}^{(t)}$ where $\mathbf{w}^{(t)}$ is the weight vector at iteration $t$ of the algorithm and $T$ is the number of iterations, and then use $\bar{\mathbf{w}}$ when making classifications on new data.
#
# To use this technique in your classifier, add the keyword argument `average=True` to the `SGDClassifier` function. Try it now.
#
# #### Deliverable 2.3: Compare the initial training/test accuracies to the training/test accuracies after doing averaging. What happens? Why do you think averaging the weights from different iterations has this effect?
#
# [your answer here]

# %%
classifier = SGDClassifier(loss='perceptron', max_iter=1000, tol=1.0e-12, random_state=123)
classifier.fit(X, Y)

print("Number of SGD iterations: %d" % classifier.n_iter_)
print("Training accuracy: %0.6f" % accuracy_score(Y, classifier.predict(X)))
print("Testing accuracy: %0.6f" % accuracy_score(Y_test, classifier.predict(X_test)))

print("\nFeature weights:")
args = np.argsort(classifier.coef_[0])
for a in args:
    print(" %s: %0.4f" % (feature_names[a], classifier.coef_[0][a]))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-47c7ce983da7> in <module>()
# ----> 1 classifier = SGDClassifier(loss='perceptron', max_iter=1000, tol=1.0e-12, random_state=123)
#       2 classifier.fit(X, Y)
#       3
#       4 print("Number of SGD iterations: %d" % classifier.n_iter_)
#       5 print("Training accuracy: %0.6f" % accuracy_score(Y, classifier.predict(X)))
#
# TypeError: __init__() got an unexpected keyword argument 'max_iter'

# %% [markdown]
# ## Problem 3: Logistic regression [15 points]
#
# For this problem, create a new `SGDClassifier`, this time setting the `loss` argument to `'log'`, which will train a logistic regression classifier.
#
# Once you have trained the classifier, you can use the `predict` function to get the classifications, as with perceptron. Additionally, logistic regression provides probabilities for the predictions. You can get the probabilities by calling the `predict_proba` function. This will give a list of two numbers; the first is the probability that the class is $\textrm{Android}$ and the second is the probability that the class is $\textrm{iPhone}$.
#
#
# For the first task, add the keyword argument `alpha` to the `SGDClassifier` function. This is the regularization strength, called $\lambda$ in lecture. If you don't specify `alpha`, it defaults to $0.0001$. Experiment with other values and see how this affects the outcome.
#
# #### Deliverable 3.1: Calculate the training and testing accuracy when `alpha` is one of $[0.0001, 0.001, 0.01, 0.1, 1.0, 10.0, 100.0]$. Create a plot where the x-axis is `alpha` and the y-axis is accuracy, with two lines (one for training and one for testing). Use [a log scale for the x-axis](https://matplotlib.org/examples/pylab_examples/log_demo.html) so that the `alpha` values are spaced evenly.
#
# [your solution should either be plotted below, or included in a separate PDF]
#
# #### Deliverable 3.2: Examine the classifier probabilities using the `predict_proba` function when training with different values of `alpha`. What do you observe? How does `alpha` affect the prediction probabilities, and why do you think this happens?
#
# [your answer here]
#
# <br />
#
# Now remove the `alpha` argument so that it goes back to the default value. We'll now look at the effect of the learning rate. By default, `sklearn` uses an "optimal" learning rate based on some heuristics that work well for many problems. However, it can be good to see how the learning rate can affect the algorithm.
#
# For this task, add the keyword argument `learning_rate` to the `SGDClassifier` function and set the value to `invscaling`. This defines the learning rate at iteration $t$ as: $\eta_t = \frac{\eta_0}{t^a}$, where $\eta_0$ and $a$ are both arguments you have to define in the `SGDClassifier` function, called `eta_0` and `power_t`, respectively. Experiment with different values of `eta_0` and `power_t` and see how they affect the number of iterations it takes the algorithm to converge. You will often find that it will not finish within the maximum of $1000$ iterations.
#
# #### Deliverable 3.3: Fill in the table below with the number of iterations for values of `eta_0` in $[10.0, 100.0, 1000.0, 10000.0]$ and values of `power_t` in $[0.5, 1.0, 2.0]$. You may find it easier to write python code that can output the markdown for the table, but if you do that place the output here. If it does not converge within the maximum number of iterations (set to $1000$ by `max_iters`), record $1000$ as the number of iterations.
#
# | `eta_0`   | `power_t` | # Iterations |
# |-----------|-----------|--------------|
# | $10.0$    | $0.5$     |              |
# | $10.0$    | $1.0$     |              |
# | $10.0$    | $2.0$     |              |
# | $100.0$   | $0.5$     |              |
# | $100.0$   | $1.0$     |              |
# | $100.0$   | $2.0$     |              |
# | $1000.0$  | $0.5$     |              |
# | $1000.0$  | $1.0$     |              |
# | $1000.0$  | $2.0$     |              |
# | $10000.0$ | $0.5$     |              |
# | $10000.0$ | $1.0$     |              |
# | $10000.0$ | $2.0$     |              |
#
# #### Deliverable 3.4: Describe how `eta_0` and `power_t` affect the learning rate based on the formula (e.g., if you increase `power_t`, what will this do to the learning rate?), and connect this to what you observe in the table above.
#
# [your answer here]
#
# <br />
#
# Now remove the `learning_rate`, `eta_0`, and `power_t` arguments so that the learning rate returns to the default setting. For this final task, we will experiment with changing the threshold at which the probability of a class must be before making a prediction.
#
# The code below includes a function called `threshold` which takes as input the classification probabilities of the data (called `probs`, which is given by the function `predict_proba`) and a threshold (called `tau`, a scalar that should be a value between $0$ and $1$). It will classify each instance as $\textrm{Android}$ if the probability of being $\textrm{Android}$ is greater than `tau`, otherwise it will classify the instance as $\textrm{iPhone}$. Note that if you set `tau` to $0.5$, the `threshold` function should give you exactly the same output as the classifier `predict` function.
#
# You should find that increasing the threshold causes the accuracy to drop. This makes sense, because you are classifying some things as $\textrm{iPhone}$ even though it's more probable that they are $\textrm{Android}$. So why do this? Suppose you care more about accurately identifying the $\textrm{Android}$ tweets and you don't care as much about `iPhone` tweets. You want to be confident that when you classify a tweet as $\textrm{Android}$ that it really is $\textrm{Android}$.
#
# There is a metric called _precision_ which measures something like accuracy but for one specific class. Whereas accuracy is the percentage of tweets that were correctly classified, the precision of $\textrm{Android}$ would be the percentage of tweets classified as $\textrm{Android}$ that were correctly classified. (In other words, the number of tweets classified as $\textrm{Android}$ whose correct label was $\textrm{Android}$, divided by the number of tweets classified as $\textrm{Android}$.)
#
# You can use the [`precision_score`](http://scikit-learn.org/stable/modules/generated/sklearn.metrics.precision_score.html#sklearn.metrics.precision_score) function from `sklearn` to calculate the precision. It works just like the `accuracy_score` function, except you have to add an additional keyword argument, `pos_label='Android'`, which tells it that $\textrm{Android}$ is the class you want to calculate the precision of.
#
# #### Deliverable 3.5: Calculate the testing precision when the value of `tau` for thresholding is one of $[0.5, 0.6, 0.7, 0.8, 0.9, 0.95, 0.99]$. Create a plot where the x-axis is `tau` and the y-axis is precision.
#
# [your solution should either be plotted below, or included in a separate PDF]
#
# #### Deliverable 3.6: Describe what you observe with thresholding (e.g., what happens to precision as the threshold increases?), and explain why you think this happens.
#
# [your answer here]

# %%
# use this function for deliverable 3.5
def threshold(probs, tau):
    return np.where(probs[:,0] > tau, 'Android', 'iPhone')

# your logistic regression code here

classifier = SGDClassifier(loss='log', max_iter=1000, tol=1.0e-12, random_state=123)
classifier.fit(X, Y)

# %% [markdown]
# ## Problem 4: Sparse learning [5604: 4 points; 4604: +2 EC points]
#
# Add the `penalty` argument to `SGDClassifier` and set the value to `'l1'`, which tells the algorithm to use L1 regularization instead of the default L2. Recall from lecture that L1 regularization encourages weights to stay at exactly $0$, resulting in a more "sparse" model than L2. You should see this effect if you examine the values of `classifier.coef_`.
#
# #### Deliverable 4.1: Write a function to calculate the number of features whose weights are nonzero when using L1 regularization. Calculate the number of nonzero feature weights when `alpha` is one of $[0.00001, 0.0001, 0.001, 0.01, 0.1]$. Create a plot where the x-axis is `alpha` and the y-axis is the number of nonzero weights, using a log scale for the x-axis.
#
# [your solution should either be plotted below, or included in a separate PDF]

# %%
# your code here

# %% [markdown]
# ## Problem 5: Feedback [+1 EC point]
#
# #### Deliverable 5.1: Approximately how much time did you spend on this assignment?
#
# About 8 hours
#
#
# #### Deliverable 5.2: Do you have requests or suggestions for something else you would have liked to have covered in this assignment or to cover in the next assignment?
